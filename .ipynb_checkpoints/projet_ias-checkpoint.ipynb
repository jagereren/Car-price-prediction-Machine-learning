# %% [markdown]
# # Projet Machine learning
#
# # Objectif :
# - Comprendre du mieux possible nos données
# - prédire les prix des voitures d'occasion avec des caractéristiques données en nous référant sur notre target variable **price**
#
# ### Analyse de Forme :
# - **Variable target :** price
# - **Lignes et colonnes :** 8128, 13
# - **Types de variables :**
# - **Analyse des valeurs manquantes :**
#
# ### Analyse de Fond :
# - **Visualisation de la target** :
# - **Signification des variables** :
# - **Relation features / target** :
#
#
#
#
# ## Visualisation des données

# %% [markdown]
# Importer les librairies utilisées

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures,LabelEncoder,OrdinalEncoder,LabelBinarizer,OneHotEncoder
from sklearn.metrics import mean_squared_error
from utilities import supprimer_unit

# %% [markdown]
# Importer le fichier csv qui contient le dataset des voitures et les features relatives pour chaque voiture

# %%
cars = pd.read_csv('data/Car details v3.csv')
cars
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %% [markdown]
# Les dimensions et la description de notre dataset :

# %%
cars.shape
# Out:
# (8128, 13)

# %% [markdown]
# On voit qu'il faut nettoyer les lignes où des null sont présents :

# %%
cars.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %% [markdown]
# Visualisation des catégories des attributs catégoriels dont certains que l'on transformera :

# %%
for col in cars.select_dtypes('object'):
    print(f'{col :-<50} {cars[col].unique()}')
    print('\n')
# Out:
# name---------------------------------------------- ['Maruti Swift Dzire VDI' 'Skoda Rapid 1.5 TDI Ambition'
#  'Honda City 2017-2020 EXi' ... 'Tata Nexon 1.5 Revotorq XT'
#  'Ford Freestyle Titanium Plus Diesel BSIV'
#  'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV']
#
#
# fuel---------------------------------------------- ['Diesel' 'Petrol' 'LPG' 'CNG']
#
#
# seller_type--------------------------------------- ['Individual' 'Dealer' 'Trustmark Dealer']
#
#
# transmission-------------------------------------- ['Manual' 'Automatic']
#
#
# owner--------------------------------------------- ['First Owner' 'Second Owner' 'Third Owner' 'Fourth & Above Owner'
#  'Test Drive Car']
#
#
# mileage------------------------------------------- ['23.4 kmpl' '21.14 kmpl' '17.7 kmpl' '23.0 kmpl' '16.1 kmpl' '20.14 kmpl'
#  '17.3 km/kg' '23.59 kmpl' '20.0 kmpl' '19.01 kmpl' '17.3 kmpl'
#  '19.3 kmpl' nan '18.9 kmpl' '18.15 kmpl' '24.52 kmpl' '19.7 kmpl'
# ...

# %%
cars["fuel"].value_counts(normalize=True).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='fuel'>

# %%
cars["seller_type"].value_counts(normalize=True).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='seller_type'>

# %%
cars["transmission"].value_counts(normalize=True).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='transmission'>

# %%
cars["owner"].value_counts(normalize=True).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='owner'>

# %% [markdown]
# On visualise la proportion en chiffres cette fois des valeurs dans les attributs catégoriels (outre les valeurs numériques)

# %%
for col in ['seller_type','transmission','fuel', 'owner']:
    print(cars[col].value_counts()/cars.shape[0],'\n')
# Out:
# Individual          0.832431
# Dealer              0.138533
# Trustmark Dealer    0.029035
# Name: seller_type, dtype: float64
#
# Manual       0.870817
# Automatic    0.129183
# Name: transmission, dtype: float64
#
# Diesel    0.541585
# Petrol    0.446727
# CNG       0.007013
# LPG       0.004675
# Name: fuel, dtype: float64
#
# First Owner             0.650714
# Second Owner            0.258981
# Third Owner             0.068282
# Fourth & Above Owner    0.021407
# Test Drive Car          0.000615
# Name: owner, dtype: float64

# %% [markdown]
# ## Matrice de correlation  :
# Avec cette matrice, nous pouvons voir que l'attribut owner est très peu corrélé avec 'selling_price', il serait donc intéréssant de s'en débarasser par la suite.

# %%
plt.figure(figsize=(18,8))
sns.heatmap(cars.corr(),annot=True,cmap= 'Spectral')
plt.show()

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# On convertit les roupies en euros

# %%
def rupees_to_euros(elem):
    return elem*0.01211

cars['selling_price'] = cars['selling_price'].apply(rupees_to_euros)
cars
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014        5449.50     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014        4480.70     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006        1913.38     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010        2724.75     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007        1574.30     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013        3875.20     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007        1634.85     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009        4626.02     120000  Diesel
# 8126               Tata Indigo CR4  2013        3511.90      25000  Diesel
# 8127               Tata Indigo CR4  2013        3511.90      25000  Diesel
#
# ...

# %% [markdown]
# On supprime les null puis on reset les index pour qu'ils s'adaptent.

# %%
cars = cars.dropna()
cars = cars.reset_index(drop=True) 
cars
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014        5449.50     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014        4480.70     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006        1913.38     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010        2724.75     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007        1574.30     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 7901             Hyundai i20 Magna  2013        3875.20     110000  Petrol
# 7902         Hyundai Verna CRDi SX  2007        1634.85     119000  Diesel
# 7903        Maruti Swift Dzire ZDi  2009        4626.02     120000  Diesel
# 7904               Tata Indigo CR4  2013        3511.90      25000  Diesel
# 7905               Tata Indigo CR4  2013        3511.90      25000  Diesel
#
# ...

# %% [markdown]
# On remarque bien qu'il n'y a plus de valeur nulle

# %%
cars.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %% [markdown]
# On supprime certains attributs : name a une faible corrélation avec le prix, torque est difficilement lisible et seats a également une faible corrélation avec le prix, nous pouvons donc nous en débarasser .

# %%
cars = cars.drop(['torque','seats','name'],axis=1)
cars
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014        5449.50     145500  Diesel  Individual       Manual
# 1     2014        4480.70     120000  Diesel  Individual       Manual
# 2     2006        1913.38     140000  Petrol  Individual       Manual
# 3     2010        2724.75     127000  Diesel  Individual       Manual
# 4     2007        1574.30     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 7901  2013        3875.20     110000  Petrol  Individual       Manual
# 7902  2007        1634.85     119000  Diesel  Individual       Manual
# 7903  2009        4626.02     120000  Diesel  Individual       Manual
# 7904  2013        3511.90      25000  Diesel  Individual       Manual
# 7905  2013        3511.90      25000  Diesel  Individual       Manual
#
#                      owner     mileage   engine   max_power
# 0              First Owner   23.4 kmpl  1248 CC      74 bhp
# ...

# %% [markdown]
# Ici nous supprimons les valeurs LPG et CNG pour l'attribut de fuel, Trustmark Dealer pour l'attribut de seller_type, Third Owner, Fourth  & Above Owner et Test Drive pour l'attribut owner. Cela nous permet par la suite de les encoder binairement.

# %%
cars = cars.drop(cars[cars.fuel == 'LPG'].index)
cars = cars.drop(cars[cars.fuel == 'CNG'].index)
cars = cars.drop(cars[cars.seller_type == 'Trustmark Dealer'].index)
cars = cars.drop(cars[cars.owner == 'Third Owner'].index)
cars = cars.drop(cars[cars.owner == 'Fourth & Above Owner'].index)
cars = cars.drop(cars[cars.owner == 'Test Drive Car'].index)

cars = cars.reset_index(drop=True)

# %%
for col in ['seller_type','transmission','fuel', 'owner']:
    print(cars[col].value_counts()/cars.shape[0],'\n')
# Out:
# Individual    0.841405
# Dealer        0.158595
# Name: seller_type, dtype: float64
#
# Manual       0.868151
# Automatic    0.131849
# Name: transmission, dtype: float64
#
# Diesel    0.565563
# Petrol    0.434437
# Name: fuel, dtype: float64
#
# First Owner     0.717363
# Second Owner    0.282637
# Name: owner, dtype: float64

# %% [markdown]
# Ici nous utilisons la fonction que nous avons définie dans le fichier utilities.py, supprimer_unit pour ne garder que la valeur numérique des attributs cités

# %%
supprimer_unit(cars,'max_power','bhp')

# %%
supprimer_unit(cars,'mileage', 'kmpl')

# %%
supprimer_unit(cars,'engine', 'CC')

# %% [markdown]
# Ensuite, on supprime les prix aberrants

# %%
cars = cars[cars['selling_price']<60000] 

fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(cars.index,cars['selling_price'])
 
# x-axis label
ax.set_xlabel('Index')
 
# y-axis label
ax.set_ylabel('Prix')
plt.show()

# %% [markdown]
# On s'occupe ici du déséquilibre pour les attributs seller_type, transmission, fuel, owner, pour cela on trie tout d'abord par owner en commençant

# %%
cars.sort_values(by=['owner'],ascending=False,inplace=True)
cars.sort_values(by=['seller_type','transmission'],inplace=True)
cars.drop(cars.index[2000:7582], axis=0,inplace=True)

for col in ['seller_type','transmission','fuel','owner']:
    print(cars[col].value_counts()/cars.shape[0],'\n')
# Out:
# Individual    0.505
# Dealer        0.495
# Name: seller_type, dtype: float64
#
# Manual       0.601
# Automatic    0.399
# Name: transmission, dtype: float64
#
# Diesel    0.598
# Petrol    0.402
# Name: fuel, dtype: float64
#
# First Owner     0.623
# Second Owner    0.377
# Name: owner, dtype: float64

# %%
#faire un one hot sur les attributs à plus de 2 valeurs, sinon labelencoder

#cols_onehot = ['fuel','seller_type', 'owner', 'transmission']

#pd.get_dummies(cars, columns=['fuel','seller_type', 'owner', 'transmission'])
#cars

cols_onehot=['fuel','seller_type','transmission','owner']
cars = pd.get_dummies(cars,columns=cols_onehot)
cars
# Out:
#       year  selling_price  km_driven  mileage  engine  max_power  fuel_Diesel  \
# 3455  2017    17559.50000       7000    14.53    1794     138.10            0
# 4562  2012    11201.75000      96000    19.62    1998     190.00            1
# 2375  2015    19981.50000      91000    12.55    2982     168.50            1
# 2831  2014     6660.50000      31000    17.21    1197     103.60            0
# 5318  2015    19981.50000      91000    12.55    2982     168.50            1
# ...    ...            ...        ...      ...     ...        ...          ...
# 2930  2011     4238.50000     100000    23.00    1396      90.00            1
# 5539  2013     4601.80000     110000    21.27    1396      88.76            1
# 4723  2011     2785.28789      40000    20.00    1399      68.00            1
# 5541  2012     4844.00000     103655    22.32    1582     126.30            1
# 3050  2008     3027.50000     110000    18.10    1493     110.00            1
#
# ...

# %% [markdown]
# ## Régressions

# %% [markdown]
# ## Division Train / Validation / Test

# %% [markdown]
# Et on passe à la division

# %%
from sklearn.model_selection import train_test_split

X = cars[['year','km_driven','mileage','engine','max_power','fuel_Diesel','fuel_Petrol','seller_type_Dealer','seller_type_Individual','transmission_Automatic','transmission_Manual','owner_First Owner','owner_Second Owner']]
y = cars['selling_price'] # variable de prédiction

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2, random_state=700) # on stocke dans des valeurs de sortie, random_state pour éviter que ça ne change
cars.head()
# Out:
#       year  selling_price  km_driven  mileage  engine  max_power  fuel_Diesel  \
# 3455  2017       17559.50       7000    14.53    1794      138.1            0
# 4562  2012       11201.75      96000    19.62    1998      190.0            1
# 2375  2015       19981.50      91000    12.55    2982      168.5            1
# 2831  2014        6660.50      31000    17.21    1197      103.6            0
# 5318  2015       19981.50      91000    12.55    2982      168.5            1
#
#       fuel_Petrol  seller_type_Dealer  seller_type_Individual  \
# 3455            1                   1                       0
# 4562            0                   1                       0
# 2375            0                   1                       0
# 2831            1                   1                       0
# 5318            0                   1                       0
#
#       transmission_Automatic  transmission_Manual  owner_First Owner  \
# ...

# %% [markdown]
# ## Modèles

# %% [markdown]
# Modèle de la régression linéaire, nous avons l'ordonnée à l'origine et les coefficients de l'équation permettant de déterminer le prix d'une voiture. <br>
# Nous en avons aussi déduit un taux de variation et un pourcentage de prédictions correctes (20% de variation) entre le prix attendu et le prix prédit pour chaque ligne du test set.

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

mlr = LinearRegression()  
mlr.fit(X_train, y_train)

print("Ordonnée à l'origine : ", mlr.intercept_)
print("Coefficients:")
print(list(zip(X_train, mlr.coef_)) ,'\n')


y_pred= mlr.predict(X_test)

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('Model Score: ', mlr.score(X_test,y_test))

#Predicted values

#print("Prediction for test set: {}".format(y_pred_mlr))

# compare
mlr_diff = pd.DataFrame({'Prix attendu': y_test, 'Prix prédit': y_pred, 'Taux de variation' : ((y_pred-y_test)/y_test)*100})

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
display(mlr_diff.head())

mlr_stats = mlr_diff[(mlr_diff['Taux de variation'] <20) & (mlr_diff['Taux de variation'] > -20)]
print('Pourcentage de prédictions plutôt correctes : ',len(mlr_stats)/len(mlr_diff))
# Out:
# Ordonnée à l'origine :  -1510997.9970991288
# Coefficients:
# [('year', 750.0086051585366), ('km_driven', -0.006315622145491917), ('mileage', -167.8814150235551), ('engine', -2.9665703333740834), ('max_power', 177.2224947109516), ('fuel_Diesel', 1773.5199910215852), ('fuel_Petrol', -1773.5199910215863), ('seller_type_Dealer', 233.29156697296528), ('seller_type_Individual', -233.29156697296403), ('transmission_Automatic', 1028.7555368429305), ('transmission_Manual', -1028.7555368429307), ('owner_First Owner', 252.14407454714856), ('owner_Second Owner', -252.1440745471488)]
#
# Mean Absolute Error: 3783.7556718034575
# Mean Squared Error: 26971132.88256318
# Root Mean Squared Error: 5193.37394018216
# Model Score:  0.7452076839116217
#       Prix attendu   Prix prédit  Taux de variation
# 1907       2361.45    -31.860704        -101.349201
# 1060      10087.63  13021.841992          29.087229
# 1496       8295.35   8215.937230          -0.957317
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
#from sklearn import metrics
from sklearn.model_selection import train_test_split

regressor = RandomForestRegressor(n_estimators=20, random_state=0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('Score du modèle : ', regressor.score(X_test,y_test))
# accuracy_score(y_test, y_pred) accuracy est pour la classification pas régression
# Out:
# Mean Absolute Error: 1170.7990390552002
# Mean Squared Error: 5309013.695323718
# Root Mean Squared Error: 2304.1297045356882
# Score du modèle :  0.9498465303082998

# %% [markdown]
# ## To-do list

# %% [markdown]
# #### _Faire des analyses graphiques !!!_
# #### _Garder owner dans les attributs_
# #### _Parler de la différence des modèles quand on
